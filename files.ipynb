# %%
f = open(r"C:\Users\OWAIS\OneDrive\Desktop\python\dbms.txt")

# %%
print(f.read())

# %%
f.close()

# %%
with open(r"C:\Users\OWAIS\OneDrive\Desktop\python\dbms.txt") as fr:
    print(fr.read())

# %%
print(fr.read()) # this will give error as file already closed after use in with block
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(fr.read()) # this will give error as file already closed after use in with block
#
# ValueError: I/O operation on closed file.

# %%
fw = open(r"C:\Users\OWAIS\OneDrive\Desktop\python\dbms.txt","w")

f = open(r"C:\Users\OWAIS\OneDrive\Desktop\python\dbms.txt","r")

# %%
lis = f.readlines()

j=1 
for i in lis:
    print(j,i.strip())
    j += 1

# %%
bestlines = lis[2:8]

print(bestlines)

for i in bestlines:
    print(i)
# Out:
# []

# %%
fw.writelines(bestlines)
