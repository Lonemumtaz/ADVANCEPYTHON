# %%
sentence = input("enter a sentence:")
# Out:
# enter a sentence:      hello world from mumtaz lone

# %%
print(sentence.strip())
# Out:
# hello world from mumtaz lone

# %%
W = sentence.split()

# %%
NewString = "".join(word[0] for word in W)

# %%
print(NewString)
# Out:
# hwfml

# %%
print(NewString.upper())
# Out:
# HWFML

# %%
print(NewString.lower())
# Out:
# hwfml
