# %%
#pre processing : bring everthing into uniform from where we can apply python operations
with open(r"C:\Users\OWAIS\OneDrive\Desktop\python\c.txt") as f:
    #print(f.read())


    lines = f.readlines()
print(lines)
# Out:
# [' my name is mumtaz . my roll number is 230324. i live in kupwara\n', '\n', '\n', '\n', ' i am in %th sem \n', '\n', '\n', ' i am cse student']

# %%
#step1
for i in lines:
    i = i.lower()

#print(lines[0]) no change un this case 

length = len(lines)

for i in range(length):
    lines[i] = lines[i].lower()

print(lines[0])    # here change will occur here
# Out:
#  my name is mumtaz . my roll number is 230324. i live in kupwara

# %%
print(lines)
# Out:
# [' my name is mumtaz . my roll number is 230324. i live in kupwara\n', '\n', '\n', '\n', ' i am in %th sem \n', '\n', '\n', ' i am cse student']

# %%
# step2 :remove unwanted characters from the text 
# for i in range (length):
    # lines[i] = lines[i].replace('\n', " ")


unchars = ['\n','.',',']


for i in range(length):
    for j in unchars:
        lines[i] = lines[i].replace(j," ")

# %%
print(lines)
# Out:
# [' my name is mumtaz   my roll number is 230324  i live in kupwara ', ' ', ' ', ' ', ' i am in %th sem  ', ' ', ' ', ' i am cse student']

# %%
# step3 : now convert this entire list into a single string and then do the split() operation to get the word count

strs = ""

for i in range(length):
    strs += lines[i]+ " "


print(strs)
# Out:
#  my name is mumtaz   my roll number is 230324  i live in kupwara         i am in %th sem        i am cse student

# %%
words = strs.split()
print(words)
print(len(words))
# Out:
# ['my', 'name', 'is', 'mumtaz', 'my', 'roll', 'number', 'is', '230324', 'i', 'live', 'in', 'kupwara', 'i', 'am', 'in', '%th', 'sem', 'i', 'am', 'cse', 'student']
# 22

# %%
#step 4: create any empty dictionary


frq = {}

for word in words:
