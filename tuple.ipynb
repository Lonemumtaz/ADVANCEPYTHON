# %%
#TUPLE>>>>
#do same what we do in lists ... and so on....
r1 = ("adeeb" , 230321 , "IITB")
print(type(r1))
print(r1)
print(r1[0])
print(r1[-1])
# Out:
# <class 'tuple'>
# ('adeeb', 230321, 'IITB')
# adeeb
# IITB

# %%
for i in r1:
    print(i)
# Out:
# adeeb
# 230321
# IITB
